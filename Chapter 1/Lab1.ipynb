# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Awards = pd.read_excel('data/Film_Awards.xlsx')
Awards
# Out:
#     Best Picture          Unnamed: 1  \
# 0           Year       Academy Award
# 1           2019            Parasite
# 2           2018          Green Book
# 3           2017  The Shape of Water
# 4            NaN                 NaN
# 5            NaN                 NaN
# 6     Best Actor                 NaN
# 7           Year       Academy Award
# 8           2019     Joaquin Phoenix
# 9           2018          Rami Malek
# 10          2017         Gary Oldman
# 11           NaN                 NaN
# 12           NaN                 NaN
# 13  Best Actress                 NaN
# 14          Year       Academy Award
# 15          2019     Renée Zellweger
# 16          2018       Olivia Colman
# 17          2017   Frances McDormand
#
#                                    Unnamed: 2  \
# 0                                    Director
# 1                                Bong Joon-ho
# 2                              Peter Farrelly
# 3                          Guillermo del Toro
# ...

# %%
df = pd.read_excel('data/Film_Awards.xlsx')

# %%
df.columns = ['Year','Academy Award','Director/Film-A','Golden Globe-Drama','Director/Film-D','Golden Globe-Musical or Comedy','Director/Film-MC']

# %%
df.loc[1, ['Golden Globe-Drama']] = ['1917']
df.loc [16, ['Golden Globe-Musical or Comedy','Director/Film-MC']] = ['Olivia Colman','The Favourite']
df
# Out:
#             Year       Academy Award  \
# 0           Year       Academy Award
# 1           2019            Parasite
# 2           2018          Green Book
# 3           2017  The Shape of Water
# 4            NaN                 NaN
# 5            NaN                 NaN
# 6     Best Actor                 NaN
# 7           Year       Academy Award
# 8           2019     Joaquin Phoenix
# 9           2018          Rami Malek
# 10          2017         Gary Oldman
# 11           NaN                 NaN
# 12           NaN                 NaN
# 13  Best Actress                 NaN
# 14          Year       Academy Award
# 15          2019     Renée Zellweger
# 16          2018       Olivia Colman
# 17          2017   Frances McDormand
#
#                               Director/Film-A  \
# 0                                    Director
# 1                                Bong Joon-ho
# 2                              Peter Farrelly
# 3                          Guillermo del Toro
# ...

# %%
df.insert(loc=0,column='Award',value=[0,'Best Picture',0,0,0,0,'Best Actor',0,0,0,0,0,0,'Best Actress',0,0,0,0])
df
# Out:
#            Award          Year       Academy Award  \
# 0              0          Year       Academy Award
# 1   Best Picture          2019            Parasite
# 2              0          2018          Green Book
# 3              0          2017  The Shape of Water
# 4              0           NaN                 NaN
# 5              0           NaN                 NaN
# 6     Best Actor    Best Actor                 NaN
# 7              0          Year       Academy Award
# 8              0          2019     Joaquin Phoenix
# 9              0          2018          Rami Malek
# 10             0          2017         Gary Oldman
# 11             0           NaN                 NaN
# 12             0           NaN                 NaN
# 13  Best Actress  Best Actress                 NaN
# 14             0          Year       Academy Award
# 15             0          2019     Renée Zellweger
# 16             0          2018       Olivia Colman
# ...

# %%
df.drop([0,4,5,7,11,12,14])
# Out:
#            Award          Year       Academy Award  \
# 1   Best Picture          2019            Parasite
# 2              0          2018          Green Book
# 3              0          2017  The Shape of Water
# 6     Best Actor    Best Actor                 NaN
# 8              0          2019     Joaquin Phoenix
# 9              0          2018          Rami Malek
# 10             0          2017         Gary Oldman
# 13  Best Actress  Best Actress                 NaN
# 15             0          2019     Renée Zellweger
# 16             0          2018       Olivia Colman
# 17             0          2017   Frances McDormand
#
#                               Director/Film-A  \
# 1                                Bong Joon-ho
# 2                              Peter Farrelly
# 3                          Guillermo del Toro
# 6                                         NaN
# 8                                       Joker
# 9                           Bohemian Rhapsody
# ...
