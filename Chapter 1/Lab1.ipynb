# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Awards = pd.read_excel('data/Film_Awards.xlsx')
Awards
# Out:
#     Best Picture          Unnamed: 1  \
# 0           Year       Academy Award
# 1           2019            Parasite
# 2           2018          Green Book
# 3           2017  The Shape of Water
# 4            NaN                 NaN
# 5            NaN                 NaN
# 6     Best Actor                 NaN
# 7           Year       Academy Award
# 8           2019     Joaquin Phoenix
# 9           2018          Rami Malek
# 10          2017         Gary Oldman
# 11           NaN                 NaN
# 12           NaN                 NaN
# 13  Best Actress                 NaN
# 14          Year       Academy Award
# 15          2019     Renée Zellweger
# 16          2018       Olivia Colman
# 17          2017   Frances McDormand
#
#                                    Unnamed: 2  \
# 0                                    Director
# 1                                Bong Joon-ho
# 2                              Peter Farrelly
# 3                          Guillermo del Toro
# ...
