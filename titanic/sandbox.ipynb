# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image, display
# %matplotlib inline

data = pd.read_csv('titanic3.csv')

# %%
ages = data["age"]

# %%
datadict = pd.DataFrame(data.dtypes)
datadict
# Out:
#                  0
# pclass       int64
# survived     int64
# name        object
# sex         object
# age        float64
# sibsp        int64
# parch        int64
# ticket      object
# fare       float64
# cabin       object
# embarked    object
# boat        object
# body       float64
# home.dest   object

# %%
# Identify missing values of the 11 columns, add the stats to the datadict
datadict["MissingVal"] = data.isnull().sum()
datadict
# Out:
#                  0  MissingVal
# pclass       int64           0
# survived     int64           0
# name        object           0
# sex         object           0
# age        float64         263
# sibsp        int64           0
# parch        int64           0
# ticket      object           0
# fare       float64           1
# cabin       object        1014
# embarked    object           2
# boat        object         823
# body       float64        1188
# home.dest   object         564

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
datadict['NUnique']=data.nunique()
datadict
# Out:
#                  0  MissingVal  Count  NUnique
# pclass       int64           0   1309        3
# survived     int64           0   1309        2
# name        object           0   1309     1307
# sex         object           0   1309        2
# age        float64         263   1046       98
# sibsp        int64           0   1309        7
# parch        int64           0   1309        8
# ticket      object           0   1309      929
# fare       float64           1   1308      281
# cabin       object        1014    295      186
# embarked    object           2   1307        3
# boat        object         823    486       27
# body       float64        1188    121      121
# home.dest   object         564    745      369

# %%
datadict['Count']=data.count()
datadict
# Out:
#                  0  MissingVal  Count  NUnique
# pclass       int64           0   1309        3
# survived     int64           0   1309        2
# name        object           0   1309     1307
# sex         object           0   1309        2
# age        float64         263   1046       98
# sibsp        int64           0   1309        7
# parch        int64           0   1309        8
# ticket      object           0   1309      929
# fare       float64           1   1308      281
# cabin       object        1014    295      186
# embarked    object           2   1307        3
# boat        object         823    486       27
# body       float64        1188    121      121
# home.dest   object         564    745      369

# %%
# False = Integers, True = Percentages
data.survived.value_counts(normalize=False)
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
sns.catplot(x='survived',col='sex',kind='count',data=data)

# %%
sns.countplot(x='survived',hue='pclass',data=data)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
ages.head(10)
# Out:
# 0    29.00
# 1     0.92
# 2     2.00
# 3    30.00
# 4    25.00
# 5    48.00
# 6    63.00
# 7    39.00
# 8    53.00
# 9    71.00
# Name: age, dtype: float64

# %%
sns.violinplot(x='sex',y='age',hue='survived',data=data,split=True)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
ages.max()
# Out:
# 80.0

# %%
ages.min()
# Out:
# 0.17

# %%
data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
data.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#      age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0     24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2    113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.00      0      0     19952   26.5500      E12        S    3    NaN
# 6  63.00      1      0     13502   77.9583       D7        S   10    NaN
# 7  39.00      0      0    112050    0.0000      A36        S  NaN    NaN
# 8  53.00      2      0     11769   51.4792     C101        S    D    NaN
# 9  71.00      0      0  PC 17609   49.5042      NaN        C  NaN   22.0
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY
# 7                      Belfast, NI
# 8              Bayside, Queens, NY
# 9              Montevideo, Uruguay

# %%
data.tail(10)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1299       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1301       3         0                     Youseff, Mr. Gerious    male  45.5
# 1302       3         0                        Yousif, Mr. Wazli    male   NaN
# 1303       3         0                    Yousseff, Mr. Gerious    male   NaN
# 1304       3         0                     Zabour, Miss. Hileni  female  14.5
# 1305       3         0                    Zabour, Miss. Thamine  female   NaN
# 1306       3         0                Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                      Zakarian, Mr. Ortin    male  27.0
# 1308       3         0                       Zimmerman, Mr. Leo    male  29.0
#
#       sibsp  parch  ticket     fare cabin embarked boat   body home.dest
# 1299      1      0    2659  14.4542   NaN        C    C    NaN       NaN
# 1300      1      0    2659  14.4542   NaN        C  NaN    NaN       NaN
# 1301      0      0    2628   7.2250   NaN        C  NaN  312.0       NaN
# 1302      0      0    2647   7.2250   NaN        C  NaN    NaN       NaN
# 1303      0      0    2627  14.4583   NaN        C  NaN    NaN       NaN
# 1304      1      0    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305      1      0    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306      0      0    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307      0      0    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308      0      0  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
data.to_excel("titanic.xlsx", sheet_name="passengers", index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspaces/AJ-DataViz/titanic/sandbox.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://codespaces%2Bajz30-uucompsci-aj-dataviz-wpqrgjgx5rg29967/workspaces/AJ-DataViz/titanic/sandbox.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> data.to_excel("titanic.xlsx", sheet_name="passengers", index=False)
#
# File /opt/python/3.10.4/lib/python3.10/site-packages/pandas/core/generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353 )
#
# File /opt/python/3.10.4/lib/python3.10/site-packages/pandas/io/formats/excel.py:888, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     884     need_save = False
#     885 else:
#     886     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888     writer = ExcelWriter(  # type: ignore[abstract]
#     889         writer, engine=engine, storage_options=storage_options
#     890     )
#     891     need_save = True
#     893 try:
#
# File /opt/python/3.10.4/lib/python3.10/site-packages/pandas/io/excel/_openpyxl.py:49, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      36 def __init__(
#      37     self,
#      38     path,
#    (...)
#      47 ):
#      48     # Use the openpyxl module as the Excel writer.
# ---> 49     from openpyxl.workbook import Workbook
#      51     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      53     super().__init__(
#      54         path,
#      55         mode=mode,
#    (...)
#      58         engine_kwargs=engine_kwargs,
#      59     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %% [markdown]
# Commands to clean up some of the data

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %% [markdown]
# Changing 1 & 0 to male & female

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %% [markdown]
# Using a neural network

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
# Out:
# 2022-09-18 19:50:09.123582: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-18 19:50:09.123619: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-09-18 19:50:19.117488: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-09-18 19:50:19.117542: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-18 19:50:19.117574: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (codespaces-80714b): /proc/driver/nvidia/version does not exist
# 2022-09-18 19:50:19.118180: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 2s 1ms/step - loss: 0.6924 - accuracy: 0.5682
# Epoch 2/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6908 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6891 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6860 - accuracy: 0.5897
# Epoch 5/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.6938
# Epoch 6/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6706 - accuracy: 0.7632
# Epoch 7/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6572 - accuracy: 0.7775
# Epoch 8/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6426 - accuracy: 0.7739
# Epoch 9/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6274 - accuracy: 0.7739
# Epoch 10/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6119 - accuracy: 0.7739
# Epoch 11/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5977 - accuracy: 0.7739
# Epoch 12/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5865 - accuracy: 0.7775
# Epoch 13/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5767 - accuracy: 0.7751
# Epoch 14/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5685 - accuracy: 0.7751
# Epoch 15/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5612 - accuracy: 0.7787
# Epoch 16/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5547 - accuracy: 0.7799
# Epoch 17/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5493 - accuracy: 0.7835
# Epoch 18/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5436 - accuracy: 0.7835
# Epoch 19/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5388 - accuracy: 0.7811
# Epoch 20/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5340 - accuracy: 0.7835
# Epoch 21/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5295 - accuracy: 0.7823
# Epoch 22/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5252 - accuracy: 0.7823
# Epoch 23/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5211 - accuracy: 0.7823
# Epoch 24/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5175 - accuracy: 0.7847
# Epoch 25/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5140 - accuracy: 0.7859
# Epoch 26/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5105 - accuracy: 0.7883
# Epoch 27/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5076 - accuracy: 0.7871
# Epoch 28/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5049 - accuracy: 0.7883
# Epoch 29/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5022 - accuracy: 0.7883
# Epoch 30/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4994 - accuracy: 0.7871
# Epoch 31/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4971 - accuracy: 0.7907
# Epoch 32/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4947 - accuracy: 0.7931
# Epoch 33/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4929 - accuracy: 0.7907
# Epoch 34/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4904 - accuracy: 0.7931
# Epoch 35/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4885 - accuracy: 0.7943
# Epoch 36/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4867 - accuracy: 0.7955
# Epoch 37/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4854 - accuracy: 0.7943
# Epoch 38/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4835 - accuracy: 0.7907
# Epoch 39/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4817 - accuracy: 0.7919
# Epoch 40/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4803 - accuracy: 0.7943
# Epoch 41/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4789 - accuracy: 0.7955
# Epoch 42/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4778 - accuracy: 0.7907
# Epoch 43/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4764 - accuracy: 0.7895
# Epoch 44/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4748 - accuracy: 0.7931
# Epoch 45/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4736 - accuracy: 0.8014
# Epoch 46/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.7990
# Epoch 47/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4712 - accuracy: 0.7990
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4700 - accuracy: 0.8014
# Epoch 49/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4690 - accuracy: 0.7978
# Epoch 50/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4680 - accuracy: 0.8002

# %%
y_pred = np.argmax(model.predict(X_test), axis=-1)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 7/7 [==============================] - 0s 2ms/step
# 0.6124401913875598
